# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy
import pywt

# %%
d1=pd.read_csv("mitbih/100.csv")
a1=open("mitbih/100annotations.txt",'r')

# %%
d1=d1["'MLII'"]

# %%
len(d1)
# Out:
# 650000

# %%
plt.plot(d1[:360])#sample rate 360hz

# %%
bd1=[]
for i in range(0,len(d1)):
    if i==1:
        bd1.append(d1[i+1]-d1[i])
        
    if i>1:
        bd1.append(d1[i]-d1[i-1])

# %%
d1
# Out:
# 0          995
# 1          995
# 2          995
# 3          995
# 4          995
# 5          995
# 6          995
# 7          995
# 8         1000
# 9          997
# 10         995
# 11         994
# 12         992
# 13         993
# 14         992
# 15         989
# 16         988
# 17         987
# 18         990
# 19         993
# 20         989
# 21         988
# 22         986
# 23         988
# 24         993
# 25         997
# 26         993
# 27         986
# 28         983
# 29         977
#           ...
# 649970     915
# 649971     915
# 649972     913
# 649973     908
# 649974     903
# 649975     895
# 649976     889
# 649977     883
# 649978     878
# 649979     875
# 649980     861
# 649981     861
# 649982     878
# 649983     901
# 649984     933
# 649985     964
# 649986    1001
# 649987    1043
# 649988    1100
# 649989    1153
# 649990    1189
# 649991    1208
# 649992    1203
# 649993    1168
# 649994    1099
# 649995    1009
# 649996     935
# ...

# %%
bd1[:]
# Out:
# [0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  5,
#  -3,
#  -2,
#  -1,
#  -2,
#  1,
#  -1,
#  -3,
#  -1,
#  -1,
#  3,
#  3,
#  -4,
#  -1,
#  -2,
#  2,
#  5,
#  4,
#  -4,
#  -7,
#  -3,
#  -6,
#  2,
#  -4,
#  -1,
#  -2,
#  -3,
#  0,
#  0,
#  2,
#  2,
#  -2,
#  -2,
#  -3,
#  0,
#  0,
#  0,
#  1,
#  -2,
#  -2,
#  4,
#  2,
#  0,
#  -1,
#  -1,
#  -4,
#  3,
#  -2,
#  4,
#  -2,
#  -2,
#  -3,
#  -1,
#  -3,
#  -5,
#  -5,
#  0,
#  -4,
#  -10,
#  -6,
#  0,
#  12,
#  19,
#  22,
#  30,
#  38,
#  51,
#  49,
#  32,
#  12,
#  -15,
#  -49,
#  -70,
#  -67,
#  -40,
#  -14,
#  2,
#  11,
#  8,
#  1,
#  -2,
#  -2,
#  3,
#  1,
#  2,
#  1,
#  -2,
#  -3,
#  -1,
#  3,
#  -4,
#  2,
#  1,
#  -1,
#  1,
#  1,
#  -1,
#  0,
#  -3,
#  -2,
#  4,
#  2,
#  4,
#  -3,
#  0,
#  -2,
#  -2,
#  1,
#  -1,
#  -1,
#  -2,
#  0,
#  3,
#  2,
#  0,
#  0,
#  -2,
#  -2,
#  5,
#  0,
#  -1,
#  0,
#  -1,
#  0,
#  -1,
#  2,
#  -2,
#  -2,
#  -1,
#  1,
#  1,
#  3,
#  2,
#  -3,
#  1,
#  -3,
#  3,
#  -1,
#  0,
#  -2,
#  0,
#  -2,
#  3,
#  0,
# ...

# %%
plt.plot(bd1[:360])#sample rate 360hz

# %%
plt.plot(bd1[:10*360])

# %%
fftd1=scipy.fft(d1)

# %%
fftd1[1:round(len(fftd1)*5/360)]=0
fftd1[int(round(np.real(fftd1[-1]))-round(len(fftd1)*5/650)):-1]=0

# %%
int(round(fftd1[-1]))-round(len(fftd1)*5/650)
# Out:
# D:\Installed_Apps\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ComplexWarning: Casting complex values to real discards the imaginary part
#   """Entry point for launching an IPython kernel.
# -549068

# %%
round(np.real(fftd1[-1]))-round(len(fftd1)*5/650)
# Out:
# -549068.0

# %%
ifftd1=np.real(scipy.ifft(fftd1))

# %%
ifftd1
# Out:
# array([923.22959585, 946.85498758, 961.89647736, ..., 896.98779433,
#        888.32943772, 899.8976241 ])

# %%
plt.plot(ifftd1[:10*360])

# %%
plt.plot(d1[:10*360])#sample rate 360hz

# %%
wbd1=pywt.wavedec(bd1,'db4')

# %%
len(wbd1[0])
# Out:
# 16

# %%
xy=wbd1[0]

# %%
len(xy)
# Out:
# 16
